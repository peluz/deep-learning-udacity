# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'originated', 'a', 'term', 'as', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['anarchism', 'term', 'originated', 'a', 'of', 'as', 'originated', 'term']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.830687
# Nearest to but: kristina, undesired, anemometer, geisel, dhamma, demi, feuding, today,
# Nearest to UNK: kammu, puppeteer, grizzly, severance, fictionalized, mechanised, brut, lom,
# Nearest to seven: easton, psychologically, sapkowski, rodeo, xa, symmetrically, maimonides, iodide,
# Nearest to is: meats, lenz, curb, emc, permanganate, acetyl, opportunistic, dies,
# Nearest to used: dyed, elfman, situation, invalid, biopsy, plowing, skits, jennie,
# Nearest to nine: dmu, barbiturates, must, shawl, uplift, additivity, skates, piaget,
# Nearest to five: bmj, cup, medians, flashback, sid, slideshow, emit, operationally,
# Nearest to only: dispatched, tot, analysts, earths, repulsion, giulio, demokratische, tainted,
# Nearest to if: fda, lowly, sportswriters, cyclonic, seismic, reinstatement, bactrian, sited,
# Nearest to over: champaign, shortly, plazas, spotted, sieges, scientifically, epi, olympics,
# Nearest to d: fischer, digby, misanthropy, conclusively, fulfilment, infallibility, homeostatic, endless,
# Nearest to was: gerund, regenerative, beaconsfield, location, craft, berkeley, pastor, pays,
# Nearest to be: galil, ton, bord, territories, bestial, stellar, namco, marketable,
# Nearest to up: multiplex, comedian, ngos, navarro, famer, selena, counselors, sophie,
# Nearest to for: damaging, beef, existentialist, hamito, cdu, zanzibar, carbonic, altitudes,
# Nearest to who: sibelius, declares, basque, piazzi, lynched, password, arabized, vietnam,
# Average loss at step 2000: 4.367111
# Average loss at step 4000: 3.859090
# Average loss at step 6000: 3.793807
# Average loss at step 8000: 3.684071
# Average loss at step 10000: 3.618581
# Nearest to but: are, dhamma, today, inherent, or, anemometer, crew, asheville,
# Nearest to UNK: h, flow, xaver, film, john, al, cryptologia, puerto,
# Nearest to seven: six, five, three, eight, nine, four, zero, two,
# Nearest to is: was, are, has, avitus, be, were, pathfinder, intellect,
# Nearest to used: invalid, plowing, forrest, ajax, dyed, rapier, due, waals,
# Nearest to nine: eight, six, five, seven, zero, four, three, two,
# Nearest to five: six, seven, nine, three, four, eight, zero, two,
# Nearest to only: cecilia, dispatched, rapper, incumbents, stations, mace, vit, outlaws,
# Nearest to if: fda, when, overstated, ecologist, cyclonic, siddur, fayette, heavy,
# Nearest to over: champaign, spotted, plazas, rudi, epi, sieges, fabricated, shortly,
# Nearest to d: b, and, capsules, fischer, conclusively, fulfilment, hopefully, infallibility,
# Nearest to was: is, were, had, has, by, are, became, unregulated,
# Nearest to be: have, lecture, speedway, is, beaten, oman, was, intersection,
# Nearest to up: lactate, noord, karami, andorra, sophie, dissolved, biham, naval,
# Nearest to for: cdu, of, after, cabinet, etsi, octahedral, cthulhu, existentialist,
# Nearest to who: he, often, also, they, and, prem, sibelius, it,
# Average loss at step 12000: 3.607102
# Average loss at step 14000: 3.570565
# Average loss at step 16000: 3.409147
# Average loss at step 18000: 3.457879
# Average loss at step 20000: 3.537571
# Nearest to but: however, though, and, which, would, that, tco, antioxidants,
# Nearest to UNK: barlaam, folklorist, www, aleph, jordan, microtubules, substantial, veterans,
# Nearest to seven: eight, six, five, three, four, nine, zero, two,
# Nearest to is: was, are, has, be, were, pathfinder, but, cystitis,
# Nearest to used: referred, known, parity, invalid, jute, waals, found, rapier,
# Nearest to nine: eight, six, seven, four, five, three, zero, two,
# Nearest to five: six, three, seven, four, eight, zero, two, nine,
# Nearest to only: dispatched, involving, demesne, cecilia, outlaws, anticipating, rapper, mace,
# Nearest to if: when, fda, filipino, where, take, ecologist, umami, siddur,
# Nearest to over: spotted, champaign, fabricated, rudi, epi, upon, plazas, meter,
# Nearest to d: b, etched, chat, aphasia, punishment, hopefully, fischer, reintroducing,
# Nearest to was: is, were, had, became, has, be, did, are,
# Nearest to be: been, have, is, was, lecture, become, by, were,
# Nearest to up: their, andorra, esophagus, noord, doren, amorphous, lafcadio, lactate,
# Nearest to for: by, in, of, with, cdu, while, official, att,
# Nearest to who: he, which, they, missiles, also, often, she, prem,
# Average loss at step 22000: 3.507521
# Average loss at step 24000: 3.489142
# Average loss at step 26000: 3.484406
# Average loss at step 28000: 3.483675
# Average loss at step 30000: 3.506312
# Nearest to but: however, and, while, though, tco, although, which, or,
# Nearest to UNK: com, fide, sergei, tz, aquino, welcoming, perrault, epistemic,
# Nearest to seven: eight, nine, five, four, six, three, zero, two,
# Nearest to is: was, has, are, intellect, be, became, makes, endothermic,
# Nearest to used: known, referred, written, found, waals, likely, live, available,
# Nearest to nine: eight, seven, six, five, four, three, zero, two,
# Nearest to five: four, three, eight, seven, six, nine, zero, two,
# Nearest to only: demesne, involving, warships, it, lard, this, broadsword, vacancies,
# Nearest to if: when, where, filipino, ecologist, overstated, like, fda, but,
# Nearest to over: spotted, fabricated, upon, into, epi, champaign, uncompromising, occupied,
# Nearest to d: b, chat, reintroducing, hopefully, polishing, monterey, shattuck, personages,
# Nearest to was: is, had, were, has, became, been, by, when,
# Nearest to be: been, lecture, have, is, make, discordianism, become, was,
# Nearest to up: andorra, them, him, lafcadio, finer, esophagus, solved, doren,
# Nearest to for: cdu, demonolatry, with, of, despite, after, cabinet, when,
# Nearest to who: he, they, which, missiles, also, she, it, never,
# Average loss at step 32000: 3.498549
# Average loss at step 34000: 3.498974
# Average loss at step 36000: 3.455787
# Average loss at step 38000: 3.299913
# Average loss at step 40000: 3.430965
# Nearest to but: however, though, and, although, while, which, are, appended,
# Nearest to UNK: b, d, agave, h, rangoon, hers, kirby, parakeet,
# Nearest to seven: six, eight, nine, five, four, three, zero, two,
# Nearest to is: was, are, if, has, cystitis, be, for, does,
# Nearest to used: referred, known, found, likely, lie, considered, written, available,
# Nearest to nine: eight, seven, six, five, four, zero, three, two,
# Nearest to five: seven, six, four, nine, eight, three, zero, two,
# Nearest to only: broadsword, incumbents, encha, gustaf, lard, demesne, vacancies, jyutping,
# Nearest to if: when, where, is, for, filipino, that, casket, suppresses,
# Nearest to over: fabricated, spotted, volatile, crucible, into, court, ethnicity, upon,
# Nearest to d: b, UNK, chat, itosu, reintroducing, hopefully, fischer, sinned,
# Nearest to was: is, became, were, had, has, been, be, subpixels,
# Nearest to be: been, have, become, is, being, were, was, are,
# Nearest to up: him, them, out, andorra, esophagus, lind, back, doren,
# Nearest to for: in, if, is, cdu, concretely, of, despite, after,
# Nearest to who: he, which, often, missiles, she, they, also, never,
# Average loss at step 42000: 3.439124
# Average loss at step 44000: 3.454328
# Average loss at step 46000: 3.449528
# Average loss at step 48000: 3.351912
# Average loss at step 50000: 3.386642
# Nearest to but: however, although, while, though, and, which, tco, since,
# Nearest to UNK: parakeet, de, html, et, gray, verdicts, vaccinations, orf,
# Nearest to seven: eight, six, nine, five, four, three, zero, one,
# Nearest to is: was, has, are, intellect, be, became, makes, contains,
# Nearest to used: referred, known, written, available, found, considered, built, seen,
# Nearest to nine: eight, seven, six, four, five, three, zero, two,
# Nearest to five: four, six, eight, seven, three, zero, nine, two,
# Nearest to only: millsaps, broadsword, demesne, warships, encha, alexandrovich, sorted, just,
# Nearest to if: when, where, while, filipino, casket, rather, know, though,
# Nearest to over: spotted, fabricated, dubliners, through, volatile, lajos, racine, uncompromising,
# Nearest to d: b, itosu, reintroducing, chat, r, e, rinpoche, etched,
# Nearest to was: is, has, were, became, had, be, been, by,
# Nearest to be: become, have, been, lecture, is, was, are, being,
# Nearest to up: them, out, him, off, back, me, doren, esophagus,
# Nearest to for: despite, against, while, cdu, cthulhu, in, after, existentialist,
# Nearest to who: he, which, they, also, she, never, often, there,
# Average loss at step 52000: 3.434509
# Average loss at step 54000: 3.425218
# Average loss at step 56000: 3.438516
# Average loss at step 58000: 3.397669
# Average loss at step 60000: 3.397670
# Nearest to but: however, and, although, see, which, though, that, tco,
# Nearest to UNK: droppings, afrikaners, enchanter, vindicated, aeronautics, algorithms, depressed, berry,
# Nearest to seven: eight, nine, six, four, five, zero, three, two,
# Nearest to is: was, are, has, be, but, cystitis, divider, makes,
# Nearest to used: referred, known, written, available, published, found, designed, seen,
# Nearest to nine: eight, six, seven, four, five, three, zero, one,
# Nearest to five: four, six, three, eight, seven, nine, zero, two,
# Nearest to only: lard, millsaps, always, first, just, involving, baldrick, demesne,
# Nearest to if: when, where, because, filipino, though, while, modernisation, before,
# Nearest to over: spotted, through, fabricated, volatile, between, about, racine, susie,
# Nearest to d: b, reintroducing, r, e, cyprian, rinpoche, f, danville,
# Nearest to was: is, had, became, were, has, been, be, subpixels,
# Nearest to be: been, become, is, have, was, were, refer, lecture,
# Nearest to up: out, them, him, off, down, back, lipi, lind,
# Nearest to for: despite, of, without, cdu, if, in, including, cartoonish,
# Nearest to who: he, never, also, which, she, still, they, not,
# Average loss at step 62000: 3.241589
# Average loss at step 64000: 3.256054
# Average loss at step 66000: 3.402071
# Average loss at step 68000: 3.391082
# Average loss at step 70000: 3.359507
# Nearest to but: however, although, which, that, though, and, while, see,
# Nearest to UNK: orf, pietro, xaver, vaccinations, capitan, conservation, mammary, stalinist,
# Nearest to seven: six, eight, nine, four, five, three, zero, two,
# Nearest to is: was, has, are, be, makes, cystitis, intellect, seems,
# Nearest to used: referred, known, written, available, found, seen, designed, responsible,
# Nearest to nine: eight, six, seven, five, four, three, zero, two,
# Nearest to five: four, six, three, seven, eight, zero, nine, two,
# Nearest to only: always, lard, necessarily, involving, diglossia, alexandrovich, still, both,
# Nearest to if: when, where, while, though, filipino, because, before, could,
# Nearest to over: spotted, fabricated, dubliners, around, epi, racine, arians, poisoning,
# Nearest to d: b, r, e, n, h, rinpoche, cyprian, reintroducing,
# Nearest to was: is, were, has, had, been, became, be, being,
# Nearest to be: been, become, is, were, being, have, by, easily,
# Nearest to up: them, out, off, down, back, him, lipi, lind,
# Nearest to for: while, without, in, if, against, to, after, concretely,
# Nearest to who: he, never, nor, which, she, astbury, contour, still,
# Average loss at step 72000: 3.374320
# Average loss at step 74000: 3.349743
# Average loss at step 76000: 3.318936
# Average loss at step 78000: 3.352256
# Average loss at step 80000: 3.380447
# Nearest to but: however, although, though, while, and, until, which, maturation,
# Nearest to UNK: smith, elizabeth, sir, corea, puerto, dr, foix, zahn,
# Nearest to seven: eight, five, six, four, nine, three, zero, two,
# Nearest to is: was, has, are, became, remains, although, be, includes,
# Nearest to used: referred, known, written, available, found, described, seen, considered,
# Nearest to nine: eight, seven, six, five, four, three, zero, one,
# Nearest to five: six, four, seven, eight, three, nine, zero, two,
# Nearest to only: lard, always, millsaps, chancellors, usually, yong, analogous, transistors,
# Nearest to if: when, though, where, before, filipino, because, rather, furthermore,
# Nearest to over: around, spotted, about, epi, arians, sparked, volatile, dubliners,
# Nearest to d: b, cyprian, f, p, e, r, n, de,
# Nearest to was: is, were, had, became, has, been, when, before,
# Nearest to be: been, have, become, being, refer, easily, is, were,
# Nearest to up: out, them, off, him, down, back, ginger, lipi,
# Nearest to for: against, cdu, while, santorum, after, ralston, tubules, shaku,
# Nearest to who: he, she, never, nor, often, harvey, contour, usually,
# Average loss at step 82000: 3.405023
# Average loss at step 84000: 3.408839
# Average loss at step 86000: 3.390750
# Average loss at step 88000: 3.354378
# Average loss at step 90000: 3.365358
# Nearest to but: however, although, and, until, which, while, they, though,
# Nearest to UNK: xaver, roadways, reims, les, legged, eth, tommy, primigenius,
# Nearest to seven: eight, six, five, four, nine, three, zero, one,
# Nearest to is: was, has, are, although, makes, be, requires, cystitis,
# Nearest to used: referred, designed, known, considered, described, available, written, found,
# Nearest to nine: eight, seven, six, five, four, zero, three, two,
# Nearest to five: four, seven, six, eight, three, nine, two, zero,
# Nearest to only: lard, alexandrovich, lorica, demesne, thatcherism, always, no, transistors,
# Nearest to if: when, where, though, filipino, furthermore, before, since, because,
# Nearest to over: through, off, around, fabricated, dubliners, lind, sparked, epi,
# Nearest to d: b, cyprian, shattuck, boldsymbol, soe, rinpoche, de, peaks,
# Nearest to was: is, had, were, became, has, been, be, subpixels,
# Nearest to be: been, become, have, was, is, being, easily, are,
# Nearest to up: out, them, off, back, him, down, ginger, together,
# Nearest to for: after, including, without, against, despite, during, cdu, while,
# Nearest to who: he, nor, she, never, which, often, also, they,
# Average loss at step 92000: 3.397642
# Average loss at step 94000: 3.255466
# Average loss at step 96000: 3.362183
# Average loss at step 98000: 3.235923
# Average loss at step 100000: 3.359304
# Nearest to but: however, although, though, and, while, which, until, fishers,
# Nearest to UNK: radiance, pietro, sergei, conjunctivitis, guy, brest, neurotransmitter, surrogate,
# Nearest to seven: eight, six, five, four, nine, three, zero, two,
# Nearest to is: was, has, became, are, becomes, be, although, being,
# Nearest to used: referred, designed, considered, found, written, described, known, available,
# Nearest to nine: eight, seven, six, five, four, zero, three, two,
# Nearest to five: four, seven, six, eight, three, zero, nine, two,
# Nearest to only: lard, millsaps, seniority, thatcherism, szasz, transistors, nickelodeon, still,
# Nearest to if: when, though, before, where, because, while, furthermore, since,
# Nearest to over: sparked, dubliners, crucible, spotted, fabricated, epi, around, volatile,
# Nearest to d: b, betrays, shattuck, hopefully, beyer, personages, cyprian, r,
# Nearest to was: is, became, has, had, were, been, although, subpixels,
# Nearest to be: been, become, being, have, refer, are, is, were,
# Nearest to up: out, them, off, him, back, down, together, anywhere,
# Nearest to for: when, including, despite, without, after, mere, maharashtri, during,
# Nearest to who: he, never, nor, she, also, still, often, and,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %% [markdown]
# Continuous Bag of Words implementation from http://www.thushv.com/natural_language_processing/word2vec-part-2-nlp-with-deep-learning-with-tensorflow-cbow/

# %%
def generate_batch(batch_size, skip_window):
    # skip window is the amount of words we're looking at from each side of a given word
    # creates a single batch
    global data_index
 
    span = 2 * skip_window + 1 # [ skip_window target skip_window ]
 
    batch = np.ndarray(shape=(batch_size,span-1), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    # e.g if skip_window = 2 then span = 5
    # span is the length of the whole frame we are considering for a single word (left + word + right)
    # skip_window is the length of one side
 
    # queue which add and pop at the end
    buffer = collections.deque(maxlen=span)
 
    #get words starting from index 0 to span
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
 
    for i in range(batch_size):
        target = skip_window  # target label at the center of the buffer
        target_to_avoid = [ skip_window ] # we only need to know the words around a given word, not the word itself

        col_idx = 0
        for j in range(span):
            if j==span//2:
                continue
            # e.g. i=0, j=0 => 0; i=0,j=1 => 1; i=1,j=0 => 2
            batch[i,col_idx] = buffer[j] # [skip_window] => middle element
            col_idx += 1
        labels[i, 0] = buffer[target]
 
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
 
    assert batch.shape[0]==batch_size and batch.shape[1]== span-1
    return batch, labels

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size,2*skip_window])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embeds = None
  for i in range(2*skip_window):
    embedding_i = tf.nn.embedding_lookup(embeddings, train_dataset[:,i])
    emb_x,emb_y = embedding_i.get_shape().as_list()
    if embeds is None:
        embeds = tf.reshape(embedding_i,[emb_x,emb_y,1])
    else:
        embeds = tf.concat([embeds,tf.reshape(embedding_i,[emb_x,emb_y,1])], 2)
        
  assert embeds.get_shape().as_list()[2]==2*skip_window
  avg_embed =  tf.reduce_mean(embeds,2,keep_dims=False)
    
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=avg_embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.588749
# Nearest to history: monck, elapsed, philosophiae, projective, arrested, helms, strolling, reeves,
# Nearest to with: ulcer, uppermost, dart, philistine, taft, menelaus, pratyeka, dominates,
# Nearest to was: predates, wpan, sketches, council, sunny, pantheistic, tomcats, frameworks,
# Nearest to zero: carboxyl, unveils, interdiction, turkmenistan, concepts, magnesians, haskell, towards,
# Nearest to see: ursinus, habits, auf, antigua, ventures, paranoid, andronicus, manipulation,
# Nearest to no: tangent, korps, tortoise, songwriters, pulitzer, audi, gertrude, wilbur,
# Nearest to between: polarity, megabit, lmi, wrestlemania, deeper, hampstead, kirsten, grateful,
# Nearest to other: craving, patience, poetical, extends, gimmicks, jabir, palaestina, ogilvie,
# Nearest to b: goebbels, romany, gec, ammonia, isidore, thor, operational, landlords,
# Nearest to than: ninja, sleepless, infer, gokturk, packaged, gauze, amazonas, vent,
# Nearest to there: seen, hmac, jingles, ammunition, ogg, dramatization, designed, gh,
# Nearest to his: neg, unmarried, manny, bedside, noel, widowed, iles, poses,
# Nearest to who: cardboard, cher, ionization, avestan, swimmer, balalaika, kune, warmth,
# Nearest to as: effective, flensburg, star, crossover, sgi, atheromatous, reflections, darker,
# Nearest to state: arch, statements, elbe, bubblegum, surrounding, nephritis, channels, penderecki,
# Nearest to by: arroyo, interrogated, hallelujah, gabab, anthology, bartolom, insurer, analyzing,
# Average loss at step 2000: 4.069139
# Average loss at step 4000: 3.544686
# Average loss at step 6000: 3.349537
# Average loss at step 8000: 3.300769
# Average loss at step 10000: 3.238920
# Nearest to history: hardwood, revert, british, navy, misrepresented, animist, elapsed, anglo,
# Nearest to with: reproductions, into, sagittarius, scavenging, ulcer, under, outweighed, namely,
# Nearest to was: is, had, were, has, predates, lawgiver, be, became,
# Nearest to zero: five, seven, eight, nine, four, six, radii, three,
# Nearest to see: sha, habits, ursinus, departs, references, knight, antigua, dewdney,
# Nearest to no: korps, pulitzer, always, compostela, profiling, rohde, audi, unification,
# Nearest to between: megabit, deeper, polarity, kirsten, poultry, lmi, validity, luc,
# Nearest to other: various, poetical, meteors, many, albertine, frequency, craving, mcnamara,
# Nearest to b: d, gec, ammonia, stratocaster, flaherty, organelle, arminians, gomoku,
# Nearest to than: packaged, ninja, or, gokturk, adornment, inquest, vent, solid,
# Nearest to there: still, they, seen, which, willis, designed, compulsory, you,
# Nearest to his: her, their, the, its, s, progenitor, leadbelly, noel,
# Nearest to who: he, which, she, beos, lagi, cardboard, avestan, neonatal,
# Nearest to as: mackenzie, through, korn, flywheel, atanasoff, when, dared, star,
# Nearest to state: statements, hailie, governor, grandpa, blacklist, revue, vacation, homerun,
# Nearest to by: misdemeanor, from, ethica, entente, be, interrogated, arroyo, westernized,
# Average loss at step 12000: 3.186012
# Average loss at step 14000: 3.071680
# Average loss at step 16000: 3.062751
# Average loss at step 18000: 3.029033
# Average loss at step 20000: 3.075496
# Nearest to history: hardwood, revert, british, navy, anglo, orwell, development, misrepresented,
# Nearest to with: between, into, reproductions, through, sagittarius, when, drill, by,
# Nearest to was: is, were, had, became, be, has, been, does,
# Nearest to zero: six, eight, five, seven, nine, four, two, three,
# Nearest to see: antigua, ursinus, sha, heritability, knight, habits, but, depths,
# Nearest to no: korps, always, pulitzer, abacus, profiling, audi, compostela, principia,
# Nearest to between: megabit, with, deeper, polarity, kirsten, lmi, vestigial, through,
# Nearest to other: various, many, different, meteors, exon, poetical, classical, some,
# Nearest to b: d, stratocaster, county, gec, indisputable, aga, flaherty, tsars,
# Nearest to than: or, packaged, approximately, solid, inquest, vent, tatian, overpopulation,
# Nearest to there: they, it, still, willis, he, compulsory, designed, seen,
# Nearest to his: her, their, its, the, s, firth, reins, my,
# Nearest to who: he, she, which, neonatal, beos, taped, they, eapc,
# Nearest to as: mackenzie, when, despite, flywheel, kinross, atanasoff, moderated, eager,
# Nearest to state: homerun, statements, thanksgiving, penderecki, hailie, governor, frequency, grandpa,
# Nearest to by: misdemeanor, interrogated, westernized, plateau, arroyo, ethica, with, wimsey,
# Average loss at step 22000: 3.020361
# Average loss at step 24000: 2.943010
# Average loss at step 26000: 3.046983
# Average loss at step 28000: 3.027184
# Average loss at step 30000: 2.886679
# Nearest to history: revert, anglo, hardwood, consequent, milhaud, ireland, concubinage, bitterly,
# Nearest to with: between, reproductions, scavenging, fictions, sagittarius, competency, maffei, in,
# Nearest to was: is, became, were, had, has, be, been, reigned,
# Nearest to zero: six, seven, eight, five, nine, four, three, mbit,
# Nearest to see: include, sha, loire, but, depths, immersed, heritability, allows,
# Nearest to no: korps, always, any, abacus, principia, profiling, nursery, bmc,
# Nearest to between: with, megabit, within, polarity, through, kirsten, shuttle, flavouring,
# Nearest to other: various, many, different, including, exon, meteors, are, some,
# Nearest to b: d, stratocaster, neoconservative, aga, convinces, indisputable, gec, county,
# Nearest to than: or, packaged, approximately, inquest, solid, adornment, much, tatian,
# Nearest to there: they, it, he, still, willis, compulsory, bothered, heuristics,
# Nearest to his: her, their, its, the, my, our, your, whose,
# Nearest to who: he, she, which, neonatal, never, taped, beos, eapc,
# Nearest to as: mackenzie, flywheel, despite, kinross, eager, becomes, when, someday,
# Nearest to state: homerun, thanksgiving, council, governor, hailie, blacklist, position, basenjis,
# Nearest to by: arroyo, coloration, misdemeanor, ethica, interrogated, deeper, under, corals,
# Average loss at step 32000: 2.956994
# Average loss at step 34000: 2.929752
# Average loss at step 36000: 2.934412
# Average loss at step 38000: 2.958429
# Average loss at step 40000: 2.836427
# Nearest to history: anglo, israel, concubinage, bootp, pumped, consequent, hieroglyphs, topics,
# Nearest to with: between, reproductions, competency, transpired, synge, forward, greve, vangelis,
# Nearest to was: is, became, be, had, has, were, been, predates,
# Nearest to zero: seven, eight, six, five, four, nine, three, two,
# Nearest to see: include, sha, but, fischer, allows, depths, loire, heritability,
# Nearest to no: korps, any, always, abacus, replicate, compostela, novi, profiling,
# Nearest to between: with, within, through, megabit, luc, kirsten, shuttle, polarity,
# Nearest to other: various, many, different, including, exon, gliding, gimmicks, deafness,
# Nearest to b: d, stratocaster, diz, aga, convinces, neoconservative, indisputable, confederate,
# Nearest to than: or, approximately, solid, adornment, much, inquest, overpopulation, transcended,
# Nearest to there: they, it, he, still, she, willis, which, grants,
# Nearest to his: her, their, my, its, our, your, whose, savage,
# Nearest to who: neonatal, he, never, which, she, beos, they, already,
# Nearest to as: mackenzie, eager, exhibit, schematic, moderated, cowboys, flywheel, eg,
# Nearest to state: homerun, council, thanksgiving, ethicists, blacklist, policy, position, nowhere,
# Nearest to by: arroyo, through, coloration, centrepiece, westernized, anew, interrogated, ethica,
# Average loss at step 42000: 2.905157
# Average loss at step 44000: 2.895114
# Average loss at step 46000: 2.801094
# Average loss at step 48000: 2.419348
# Average loss at step 50000: 2.623180
# Nearest to history: israel, anglo, ireland, bootp, orwell, chemist, convoluted, hieroglyphs,
# Nearest to with: between, ninlil, competency, drill, transpired, maffei, oxidize, snowflakes,
# Nearest to was: is, became, had, be, were, been, has, reigned,
# Nearest to zero: five, seven, six, four, nine, eight, three, two,
# Nearest to see: include, allows, but, fischer, sha, permian, depths, antigua,
# Nearest to no: korps, any, abacus, little, always, compostela, replicate, novi,
# Nearest to between: with, within, luc, through, shuttle, flavouring, docks, decidedly,
# Nearest to other: various, many, individual, different, exon, meteors, deafness, including,
# Nearest to b: d, county, deduction, stratocaster, hydraulic, indisputable, relativism, boudinot,
# Nearest to than: or, approximately, much, overpopulation, adornment, solid, transcended, efficient,
# Nearest to there: they, it, he, still, she, these, now, we,
# Nearest to his: their, her, its, my, your, our, the, whose,
# Nearest to who: never, neonatal, he, she, which, taped, avestan, galton,
# Nearest to as: mackenzie, flywheel, eg, eager, exhibit, moderated, korn, how,
# Nearest to state: blacklist, council, homerun, position, basenjis, policy, thanksgiving, government,
# Nearest to by: misdemeanor, through, wimsey, under, coloration, decimals, ethica, interrogated,
# Average loss at step 52000: 2.793457
# Average loss at step 54000: 2.778421
# Average loss at step 56000: 2.872989
# Average loss at step 58000: 2.843350
# Average loss at step 60000: 2.686840
# Nearest to history: anglo, bootp, israel, orwell, assessing, entomologist, ets, potemkin,
# Nearest to with: between, bombardier, maffei, apa, carries, creates, snowflakes, ulcer,
# Nearest to was: is, became, had, were, has, be, been, lawgiver,
# Nearest to zero: five, six, four, eight, seven, nine, three, two,
# Nearest to see: include, allows, fischer, lingua, permian, mamoru, but, depths,
# Nearest to no: korps, any, little, always, abacus, become, nursery, karst,
# Nearest to between: with, within, through, validity, shuttle, luc, around, docks,
# Nearest to other: various, different, many, individual, gliding, deafness, exon, hazael,
# Nearest to b: d, deduction, stratocaster, tsars, aga, troposphere, county, indisputable,
# Nearest to than: or, solid, approximately, overpopulation, efficient, much, while, transcended,
# Nearest to there: they, it, he, she, still, now, grants, we,
# Nearest to his: her, their, my, our, its, your, whose, the,
# Nearest to who: neonatal, never, she, he, beos, avestan, taped, assuring,
# Nearest to as: mackenzie, eager, flywheel, eg, someday, dme, atanasoff, gael,
# Nearest to state: government, blacklist, homerun, council, position, nowhere, basenjis, governor,
# Nearest to by: arroyo, through, deeper, williamite, anew, under, centrepiece, wimsey,
# Average loss at step 62000: 2.835966
# Average loss at step 64000: 2.845800
# Average loss at step 66000: 2.835623
# Average loss at step 68000: 2.565244
# Average loss at step 70000: 2.732751
# Nearest to history: bootp, orwell, israel, period, anglo, potemkin, eitc, assessing,
# Nearest to with: between, apa, carries, creates, ninlil, competency, transpired, bombardier,
# Nearest to was: is, became, were, had, has, be, been, neutralize,
# Nearest to zero: five, eight, six, seven, four, nine, three, u,
# Nearest to see: but, include, allows, lingua, listening, allow, bellum, loire,
# Nearest to no: korps, any, little, always, become, erg, replicate, rack,
# Nearest to between: within, with, among, validity, luc, around, greve, docks,
# Nearest to other: various, many, individual, different, several, deafness, mantras, transfers,
# Nearest to b: d, stratocaster, deduction, indisputable, county, trousers, aga, hydraulic,
# Nearest to than: or, approximately, solid, infer, overpopulation, much, while, efficient,
# Nearest to there: they, it, he, she, we, now, still, today,
# Nearest to his: her, their, my, your, our, its, whose, the,
# Nearest to who: which, neonatal, never, she, he, taped, beos, avestan,
# Nearest to as: mackenzie, destabilizing, flywheel, dme, because, someday, moderated, exhibit,
# Nearest to state: blacklist, ethicists, nowhere, homerun, government, intentional, governor, finances,
# Nearest to by: through, arroyo, under, newly, corals, misdemeanor, anew, wimsey,
# Average loss at step 72000: 2.670111
# Average loss at step 74000: 2.807682
# Average loss at step 76000: 2.716506
# Average loss at step 78000: 2.800477
# Average loss at step 80000: 2.779615
# Nearest to history: bootp, israel, orwell, potemkin, anglo, remarking, entomologist, assessing,
# Nearest to with: between, bombardier, competency, carries, ninlil, although, in, fictions,
# Nearest to was: is, became, had, has, be, were, becomes, been,
# Nearest to zero: five, seven, eight, four, six, nine, three, two,
# Nearest to see: include, but, allows, lingua, references, allow, refer, expressway,
# Nearest to no: any, korps, little, a, always, karst, demilitarized, replicate,
# Nearest to between: with, within, among, validity, decidedly, luc, kirsten, shuttle,
# Nearest to other: various, different, individual, many, several, mantras, deafness, improving,
# Nearest to b: d, deduction, stratocaster, indisputable, trousers, rebate, hydraulic, jill,
# Nearest to than: or, approximately, much, infer, and, overpopulation, solid, while,
# Nearest to there: they, it, she, he, we, now, today, still,
# Nearest to his: her, their, my, your, its, our, whose, the,
# Nearest to who: she, which, neonatal, often, he, never, taped, finally,
# Nearest to as: mackenzie, flywheel, eg, gael, eager, destabilizing, someday, lipids,
# Nearest to state: blacklist, ethicists, government, city, homerun, idea, district, intentional,
# Nearest to by: through, under, newly, arroyo, anew, misdemeanor, ethica, wimsey,
# Average loss at step 82000: 2.738562
# Average loss at step 84000: 2.701487
# Average loss at step 86000: 2.715590
# Average loss at step 88000: 2.651136
# Average loss at step 90000: 2.748666
# Nearest to history: bootp, israel, orwell, potemkin, map, anglo, entomologist, period,
# Nearest to with: between, ninlil, nautical, maffei, distressing, creates, philistine, greve,
# Nearest to was: is, were, has, became, had, be, being, lawgiver,
# Nearest to zero: eight, five, four, seven, six, nine, three, two,
# Nearest to see: include, but, allows, references, includes, lingua, expressway, mondeo,
# Nearest to no: any, korps, little, always, demilitarized, rsha, karst, become,
# Nearest to between: with, within, among, validity, greve, kirsten, around, luc,
# Nearest to other: various, different, several, individual, many, including, additional, hazael,
# Nearest to b: d, deduction, stratocaster, ozzie, relativism, propagated, que, trousers,
# Nearest to than: or, overpopulation, much, approximately, vent, solid, transcended, infer,
# Nearest to there: they, it, he, she, we, now, believed, still,
# Nearest to his: her, their, my, our, your, its, whose, the,
# Nearest to who: she, often, which, neonatal, he, taped, finally, beos,
# Nearest to as: mackenzie, eg, gael, moderated, eager, zbigniew, ras, someday,
# Nearest to state: blacklist, district, government, city, ethicists, homerun, intentional, nowhere,
# Nearest to by: through, under, arroyo, anew, during, misdemeanor, wimsey, corals,
# Average loss at step 92000: 2.703055
# Average loss at step 94000: 2.764506
# Average loss at step 96000: 2.752267
# Average loss at step 98000: 2.612111
# Average loss at step 100000: 2.770574
# Nearest to history: bootp, map, anglo, potemkin, israel, period, landmines, psr,
# Nearest to with: between, ninlil, carries, oxidize, including, greve, creates, competency,
# Nearest to was: is, became, had, were, remained, has, been, becomes,
# Nearest to zero: five, eight, seven, six, nine, four, three, two,
# Nearest to see: include, but, references, expressway, allows, lingua, includes, erne,
# Nearest to no: any, korps, little, become, always, karst, demonstration, replicate,
# Nearest to between: with, within, among, validity, docks, flavouring, through, luc,
# Nearest to other: various, different, individual, several, many, additional, hazael, babel,
# Nearest to b: d, deduction, stratocaster, f, rebate, onager, y, bumps,
# Nearest to than: or, overpopulation, approximately, secure, woensel, njazidja, transcended, solid,
# Nearest to there: they, it, she, he, we, today, now, surgically,
# Nearest to his: her, their, my, your, its, our, whose, the,
# Nearest to who: she, often, he, neonatal, actually, taped, finally, beos,
# Nearest to as: mackenzie, eg, flywheel, eager, someday, atanasoff, destabilizing, nc,
# Nearest to state: blacklist, government, homerun, nowhere, district, states, ethicists, city,
# Nearest to by: through, misdemeanor, wimsey, arroyo, corals, visitation, anew, williamite,

# %%
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
plot(two_d_embeddings, words)
